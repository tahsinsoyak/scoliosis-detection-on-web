# %%
# %mkdir /content/drive/MyDrive/scoliosis-yolov8

# %%
# %cd /content/drive/MyDrive/scoliosis-yolov8

# !pip install ultralytics
# Out:
# /content/drive/MyDrive/scoliosis-yolov8
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 778.4/778.4 kB 16.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...

# %%
# %cd /content/drive/MyDrive/scoliosis-yolov8


# !pip install roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="1RRHOcVkt2MvJx1GWNil")
project = rf.workspace("anil-mzou3").project("scoliosis-dgqy2")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# /content/drive/MyDrive/scoliosis-yolov8
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.22, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to scoliosis-1 in yolov8:: 100%|██████████| 2286/2286 [00:17<00:00, 129.76it/s]

# %%
# %cd /content/drive/MyDrive/scoliosis-yolov8
# !yolo detect train data=/content/drive/MyDrive/scoliosis-yolov8/scoliosis-1/data.yaml model=yolov8n.pt epochs=50 batch=16 imgsz=640 name="bestmodel"
# Out:
# /content/drive/MyDrive/scoliosis-yolov8
# ...
# 100% 6.23M/6.23M [00:00<00:00, 203MB/s]
# Ultralytics YOLOv8.2.22 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd /content/drive/MyDrive/scoliosis-yolov8
# !yolo detect train data=/content/drive/MyDrive/scoliosis-yolov8/scoliosis-1/data.yaml model=yolov8m.pt epochs=50 imgsz=640 name="m-bestmodel"
# Out:
# /content/drive/MyDrive/scoliosis-yolov8
# ...
# 100% 49.7M/49.7M [00:00<00:00, 187MB/s]
# Ultralytics YOLOv8.2.22 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd /content/drive/MyDrive/scoliosis-yolov8
# !yolo detect train data=/content/drive/MyDrive/scoliosis-yolov8/scoliosis-1/data.yaml model=yolov8l.pt epochs=50 imgsz=640 name="l-bestmodel"
# Out:
# /content/drive/MyDrive/scoliosis-yolov8
# ...
# 100% 83.7M/83.7M [00:00<00:00, 220MB/s]
# Ultralytics YOLOv8.2.22 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd /content/drive/MyDrive/scoliosis-yolov8
# !yolo detect train data=/content/drive/MyDrive/scoliosis-yolov8/scoliosis-1/data.yaml model=yolov8x.pt epochs=50 imgsz=640 name="x-bestmodel"
# Out:
# /content/drive/MyDrive/scoliosis-yolov8
# ...
# 100% 131M/131M [00:00<00:00, 223MB/s]
# Ultralytics YOLOv8.2.22 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
